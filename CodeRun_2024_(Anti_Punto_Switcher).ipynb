# %%
# mount google drive to save images on it
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os

os.chdir('/content/drive/MyDrive/Я-профи подготовка по машинному обучению/CodeRun/CodeRun 2024')
os.getcwd()
# Out:
# '/content/drive/MyDrive/Я-профи подготовка по машинному обучению/CodeRun/CodeRun 2024'

# %%
os.listdir()
# Out:
# ['anti-punto-switcher-public.csv', 'anti-punto-switcher-private.csv']

# %%
import pandas as pd

train = pd.read_csv('anti-punto-switcher-public.csv')
test = pd.read_csv('anti-punto-switcher-private.csv')

train.head()
# Out:
#                                                 text  \
# 0           и старательности полкового rjvfylbhf был
# 1  о котором старались умолчать tlbycndtyyj потом...
# 2                             или пуля dfc не брала,
# 3  друг друга, нестройною, но веселою b оживленно...
# 4  берейторами в расшитых попонах красивые запасн...
#
#                                                label
# 0           и старательности полкового командира был
# 1  о котором старались умолчать единственно потом...
# 2                             или пуля вас не брала,
# 3  друг друга, нестройною, но веселою и оживленно...
# 4  берейторами в расшитых попонах красивые запасн...

# %%
test
# Out:
#                                                    text
# 0     петруша, и их любовников, – сказал он. пьер, о...
# 1               мог не привлечь его внимания. наполеон,
# 2                                 деньги на карты, а то
# 3     у себя во франции на такие пустяки не j,hfoftv...
# 4     – откуда и докуда, ваше величество? – от l.hty...
# ...                                                 ...
# 4735       ghbeujnjdbntkmyfz беседа для принятия нового
# 4736             как он найдет в отрадном. чем ,kb;t он
# 4737  аустерлица, – думал он, ожидая всякую секунду ...
# 4738  по назначенным квартирам невдалеке от браунау,...
# 4739           в себя из того русского воздуха, которым
#
# [4740 rows x 1 columns]
